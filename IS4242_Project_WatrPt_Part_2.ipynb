# %% [markdown]
# **Pump it Up: Data Mining Competition**
#
# **Team: WatrPt**
#
# **Members: Ho Jun Cong Keith (A0184106L), Patt Wei Xuan, Elgin (A0183601M)**

# %%
import numpy as np
import pandas as pd
from math import sqrt
import warnings
warnings.filterwarnings('ignore')

# %%
url = 'https://raw.githubusercontent.com/keithhjc/IS4242-Project-WatrPt/main/Training%20Set%20Labels.csv?token=AMBVJ2AWO5FQJ7SIXFATVOS7SPYW6'

Y_train = pd.read_csv(url)

# %%
url = 'https://raw.githubusercontent.com/keithhjc/IS4242-Project-WatrPt/main/Training%20Set%20Values.csv?token=AMBVJ2GQ6BY5G3A4MYIAXE27SPYUG'

X_train = pd.read_csv(url)

# %%
full_set = pd.concat([X_train, Y_train.status_group], axis=1, copy=False)
full_set.head(3)
# Out:
#       id  amount_tsh  ... waterpoint_type_group status_group
# 0  69572      6000.0  ...    communal standpipe   functional
# 1   8776         0.0  ...    communal standpipe   functional
# 2  34310        25.0  ...    communal standpipe   functional
#
# [3 rows x 41 columns]

# %% [markdown]
# # Part 2: Prescriptive Analytics

# %%
# !pip install -q pyomo
# !apt-get install -y -qq glpk-utils
import pyomo.environ as pe

# %%
from pyomo.environ import value

# %% [markdown]
# ## The Problem in Words

# %% [markdown]
# To determine for each Local Government Area (LGA), which non-functional pumps can be replaced at minimum possible cost in order to serve water to everyone.
#
# Input
#
# *    Name of the LGA
#
#
#
# Output
#
# *    Names of non-functional pumps to be replaced
# *    Total cost
#
# Basically, when an LGA is inputted, we first preprocess the data by:
#
# *    Filter the dataframe according to given LGA
# *    Split the dataframe into two, namely one for functional pumps, and another for non-functional pumps
# *    Drop any duplicated pumps with the same longitude, latitude and wpt_name
# *    For pumps with the same wpt_name but different longitude and latitude, name them as their original name + a postfix number (Dupe -> Dupe1)
# *    Using the non-functional pump dataframe from step 2, for each pump, identify the nearest pump and append its name, population it can support, and cost it takes to transport

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# We start by removing records that
#
# 1.   Don't have location information (longitude or latitude == 0)
# 2.   Have pumps with 0 surrounding population (population != 0)
# 3.   Have no name for the pump (wpt_name != none)

# %%
part_2_set = full_set[['amount_tsh','longitude', 'latitude', 'wpt_name', 'lga', 'population', 'status_group']]
part_2_set = part_2_set[part_2_set['longitude'] !=0]
part_2_set = part_2_set[part_2_set['latitude'] !=0]
part_2_set = part_2_set[part_2_set['population'] !=0]
part_2_set = part_2_set[part_2_set['wpt_name'] != 'none']
part_2_set
# Out:
#        amount_tsh  longitude  ...  population    status_group
# 1             0.0  34.698766  ...         280      functional
# 2            25.0  37.460664  ...         250      functional
# 3             0.0  38.486161  ...          58  non functional
# 5            20.0  39.172796  ...           1      functional
# 10            0.0  39.209518  ...         345      functional
# ...           ...        ...  ...         ...             ...
# 59391         0.0  38.044070  ...         210  non functional
# 59394       500.0  37.634053  ...          89  non functional
# 59395        10.0  37.169807  ...         125      functional
# 59396      4700.0  35.249991  ...          56      functional
# 59399         0.0  38.104048  ...         150      functional
#
# [35771 rows x 7 columns]

# %% [markdown]
# Next we take a sample input to build our model and continue data preprocessing.
#
# The input can be any valid LGA.

# %%
##input the name of the LGA
input = 'Nanyumbu'
lga_set = part_2_set[part_2_set['lga'] == input]

# %% [markdown]
# We then continue preprocessing by first generating the construction cost to repair each pump, since the value is static and decided by TSH

# %%
##generate and preprocess construction cost for each pump
lga_set['construction_cost'] = (lga_set['amount_tsh'] * 0.05) + 100
lga_set = lga_set.drop(columns=['amount_tsh'])

# %% [markdown]
# We seperate the functional pumps from the non-functional pumps to make the data easier to work with

# %%
lga_functional = lga_set[lga_set['status_group'] == 'functional']
lga_non_functional = lga_set[lga_set['status_group'] == 'non functional']

# %% [markdown]
# For the functional set,
#
# *   We first ensure that no pumps are duplicated (duplicated pumps are defined by pumps with the same longitude, latitude and name)
#
# *   We then rename any pumps with the same name, but different longitude and latitude since we need unique values for the pump names

# %%
##Drop Duplicated pumps with the same longitude, latitude and wpt_name
lga_functional = lga_functional.drop_duplicates(subset=['longitude', 'latitude', 'wpt_name'], keep='last')

##Replace Duplicated pumps with same name but different longitude/latitude with Name + postfix number
lga_functional['wpt_name'] = lga_functional['wpt_name'] + lga_functional.groupby(['wpt_name']).cumcount().astype(str).replace('0','')

lga_functional = lga_functional.reset_index().drop(columns=['index'])
lga_functional
# Out:
#     longitude   latitude  ... status_group construction_cost
# 0   38.242246 -11.136034  ...   functional            100.00
# 1   38.358985 -11.243879  ...   functional            100.00
# 2   38.721621 -10.831273  ...   functional            100.00
# 3   38.644966 -10.829329  ...   functional            100.00
# 4   38.511580 -11.150792  ...   functional            100.00
# 5   38.529403 -11.070651  ...   functional            100.00
# 6   38.340059 -10.935739  ...   functional            100.00
# 7   38.367407 -10.922912  ...   functional            102.50
# 8   38.413291 -11.024038  ...   functional            102.50
# 9   38.164017 -11.206286  ...   functional            100.00
# 10  38.691280 -10.876677  ...   functional            102.50
# 11  38.515677 -10.895464  ...   functional            102.50
# 12  38.235595 -10.894751  ...   functional            100.00
# 13  38.550132 -11.147248  ...   functional            101.50
# 14  38.644990 -10.829333  ...   functional            100.00
# 15  38.390160 -10.930557  ...   functional            101.25
# 16  38.366044 -10.923244  ...   functional            102.50
# 17  38.390321 -10.930090  ...   functional            101.25
# 18  38.396676 -10.912563  ...   functional            100.00
# 19  38.554452 -11.146587  ...   functional            101.50
# 20  38.584980 -10.876893  ...   functional            101.50
# 21  38.274129 -11.075896  ...   functional            101.50
# 22  38.485725 -11.149465  ...   functional            150.00
# 23  38.489004 -11.142924  ...   functional            150.00
# 24  38.619875 -10.956079  ...   functional            100.00
# 25  38.358316 -10.885653  ...   functional            102.50
# 26  38.440406 -11.055669  ...   functional            102.50
# 27  38.644949 -10.829302  ...   functional            102.50
# 28  38.246152 -11.154437  ...   functional            102.50
# 29  38.528428 -11.058752  ...   functional            102.50
# 30  38.569951 -10.833884  ...   functional            100.00
# 31  38.512539 -10.848200  ...   functional            100.00
# 32  38.630967 -10.848768  ...   functional            100.00
# 33  38.585374 -11.230462  ...   functional            100.00
# 34  38.386876 -11.348178  ...   functional            101.00
# 35  38.379299 -11.053007  ...   functional            100.00
# 36  38.441305 -11.366974  ...   functional            100.00
# 37  38.722181 -10.827398  ...   functional            105.00
# 38  38.378871 -10.928478  ...   functional            101.25
# 39  38.774014 -10.955709  ...   functional            101.50
# 40  38.575274 -10.880373  ...   functional            101.50
# 41  38.500128 -11.141398  ...   functional            100.00
#
# [42 rows x 7 columns]

# %% [markdown]
# For the non-functional set, we repeat the same process:
#
# *   We first ensure that no pumps are duplicated (duplicated pumps are defined by pumps with the same longitude, latitude and name)
#
# *   We then rename any pumps with the same name, but different longitude and latitude since we need unique values for the pump names

# %%
##Drop Duplicated pumps with the same longitude, latitude and wpt_name
lga_non_functional = lga_non_functional.drop_duplicates(subset=['longitude', 'latitude', 'wpt_name'], keep='last')

##Replace Duplicated pumps with same name but different longitude/latitude with Name + postfix number
lga_non_functional['wpt_name'] = lga_non_functional['wpt_name'] + lga_non_functional.groupby(['wpt_name']).cumcount().astype(str).replace('0','')

lga_non_functional = lga_non_functional.reset_index(drop=True)
lga_non_functional
# Out:
#      longitude   latitude  ...    status_group construction_cost
# 0    38.486161 -11.155298  ...  non functional             100.0
# 1    38.691033 -10.876661  ...  non functional             100.0
# 2    38.117806 -10.925890  ...  non functional             102.5
# 3    38.119977 -10.926111  ...  non functional             100.0
# 4    38.527007 -11.164013  ...  non functional             100.0
# ..         ...        ...  ...             ...               ...
# 111  38.428913 -10.931789  ...  non functional             101.5
# 112  38.166363 -10.925159  ...  non functional             100.0
# 113  38.778164 -10.929034  ...  non functional             100.0
# 114  38.416050 -11.024982  ...  non functional             100.0
# 115  38.096892 -11.120100  ...  non functional             100.0
#
# [116 rows x 7 columns]

# %% [markdown]
# For every non-functional pump in the LGA, we then:
#
#
# 1.   Generate the cost it takes to transport water from the nearest functional pump in the LGA
# 2.   Append the name, population and cost to transport from that pump.

# %%
##Append name, population, and cost to transport
all_transport_pump = []
funct_pump_name = []
funct_pump_population = []
funct_pump_cost = []
cost = 999999999
population = "0"
wpt_name = "default"
for ind in lga_non_functional.index:
  longitude = lga_non_functional['longitude'][ind]
  latitude = lga_non_functional['latitude'][ind]
  population = lga_non_functional['population'][ind]
  for ind in lga_functional.index:
    funct_longitude = lga_functional['longitude'][ind]
    funct_latitude = lga_functional['latitude'][ind]
    current_cost = 100 + 2000*(sqrt((latitude - funct_latitude)**2 + (longitude - funct_longitude)**2))
    if current_cost < cost:
      wpt_name = lga_functional['wpt_name'][ind]
      population = lga_functional['population'][ind]
      cost = current_cost
  funct_pump_name.append(wpt_name)
  funct_pump_population.append(population)
  funct_pump_cost.append(cost)
  cost = 999999999
lga_non_functional['funct_pump_name'] = funct_pump_name
lga_non_functional['funct_pump_population'] = funct_pump_population
lga_non_functional['funct_pump_cost'] = funct_pump_cost

lga_non_functional
# Out:
#      longitude   latitude  ... funct_pump_population funct_pump_cost
# 0    38.486161 -11.155298  ...                   145      111.698356
# 1    38.691033 -10.876661  ...                    86      100.495139
# 2    38.117806 -10.925890  ...                    56      343.670861
# 3    38.119977 -10.926111  ...                    56      339.589741
# 4    38.527007 -11.164013  ...                    45      140.633776
# ..         ...        ...  ...                   ...             ...
# 111  38.428913 -10.931789  ...                   130      175.069332
# 112  38.166363 -10.925159  ...                    56      251.230448
# 113  38.778164 -10.929034  ...                    56      153.990937
# 114  38.416050 -11.024982  ...                   140      105.833089
# 115  38.096892 -11.120100  ...                    15      318.483243
#
# [116 rows x 10 columns]

# %% [markdown]
# ## Our Model

# %% [markdown]
# We start by defining our ConcreteModel and converting our data into dictionaries and Decision variables.

# %% [markdown]
# ## Decision Variables & Objective Function

# %% [markdown]
# Total cost to:
# 1. Replace non-functional pump => **[100 + 0.05(TSH)]**
#
#
# OR
# 2. Transport water to non-functional pump => **[100 + 2000(√[(Latitude - Latitude1)² + (Longitude - Longitude1)²]** multiplied by the number of functional pumps required
#
#
# For each pump,
# **Cost = X[100 + 0.05(TSH)] + (1-X)([100 + 2000(√[(Latitude1 - Latitude2)² + (Longitude1 - Longitude2)²])**
#
# Where X is either 0 or 1, 0 for water transport, and 1 for repair
#
# The decision variable in our code is represented as **pump.to_construct**, a value that can take a Boolean value of 0 or 1 and is used to represent whether a pump should be repaired or transported water.

# %%
pump = pe.ConcreteModel()

wpt_names = lga_non_functional["wpt_name"].tolist()
pump.to_construct = pe.Var(wpt_names, domain=pe.Boolean)

# %% [markdown]
# We then generate a few key value pairs to pair up our decision variable with other parameters that we will use in building our constraints

# %%
construct_costs = {nfpump: price for nfpump, price in zip(wpt_names, lga_non_functional["construction_cost"].tolist())}
transport_costs = {nfpump: price for nfpump, price in zip(wpt_names, lga_non_functional["funct_pump_cost"].tolist())}
populations = {nfpump: pop for nfpump, pop in zip(wpt_names, lga_non_functional["population"].tolist())}
functioning_populations = {nfpump: pop for nfpump, pop in zip(wpt_names, lga_non_functional["funct_pump_population"].tolist())}

# %% [markdown]
# We define our objective as the total cost it takes to either repair the pump or transport water from the nearest functional pump.
#
# The preprocessing of the data in the earlier stage allows us to easily access the name, population and cost to build to the nearest functional pump.
#
# In building the model, we first start by defining the decision variables for the model to choose. In this case, our decision variables is a **boolean value** that can either evaluate to 0 or 1, one for each pump.
#
# A pump with a decision variable value of 1 should be repaired and a pump with a decision variable value of 0 should have water transported from the nearest functional pump.
#
# This is reflected in the objective statement, as the statement minimizes the cost and only adds either the cost of the pump repair or the cost of the water transport, depending on the value of the **to_construct** decision variable.

# %%
pump.obj = pe.Objective(expr=sum(construct_costs[i]*pump.to_construct[i] for i in wpt_names) 
+ sum(transport_costs[i] * (1 - pump.to_construct[i]) for i in wpt_names), sense=pe.minimize)

# %% [markdown]
# ## Our Non-Numerical Constraints

# %% [markdown]
# 1. When a pump is functional, it can serve non-functional pumps around it.
#
# 2. Non-functional pumps can only be served by the nearest pump next to it.
#
# 3. We do not need to account for a pump serving other pumps when it is functional from being repaired.

# %% [markdown]
# ##Our Numerical Constraints

# %% [markdown]
# 1. A functional pump can serve one or many non-functional pumps, as long as it has the population capacity to do so.

# %%
def population_rule(pump):
  for name in wpt_names:
    if construct_costs[name] > transport_costs[name]:
      if populations[name] > functioning_populations[name]:
        return pe.Constraint.Infeasible
  return pe.Constraint.Feasible

pump.population_con = pe.Constraint(rule=population_rule)

pump.pprint()
# Out:
# 1 Set Declarations
#     to_construct_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :  116 : {'Zahanati Ya Nanyumbu', 'Kwa Zena Rajabu 2', 'Namajani', 'Kwa Peter', 'Mission', 'Kwa Chikwalo', 'Minazini', 'Kwa Ally Omary', 'Nandete', 'Kwa Rehema Athumani', 'Kwa Ally Mohamed', 'Shuleni', 'Kwa Kalha', 'Kwa Ghohoni', 'Kwa Yusuph Namoyo', 'Kwa Kaluma', 'Kwa Hamza 3', 'Kwa Ismail', 'Mkalia', 'Likuku', 'Kwa Rumeni 2', 'Namatunu 1', 'Kwa Mbanga', 'Mkoroshoni', 'Kwa Tindwa', 'Kwa Masisa', 'Shuleni1', 'Kwa Mtuta', 'Kwa Mwenyemaviha', 'Demuni', 'Kwa Wiliam', 'Kwa Sitta', 'Kwa Rumeni', 'Kwa Ddwani Mteule', 'Kwa Yassin', 'Kwa Kaweni Japhari', 'Lukwika Camp', 'Mkoroshoni 2', 'Shuleni2', 'Kwa Mwanahafa Rajabu', 'Kwa Nihiha', 'Shule Ya Msingi Chungu', 'Kwa Alukama 2', 'Kwa Kalambwa', 'Kwa Salimu Ally', 'Kwa Lilonde', 'Ngangasimiche', 'Kwa Mohamed Kantinda', 'Kwa Adamu Imelale', 'Kwa Chilala 2', 'Kwa Mohamed Mole', 'Nandete1', 'Kwa Makusudi', 'Kwa Awilakina', 'Barabarani', 'Kwa Chilala', 'Kwa Hamza', 'Demuni 2', 'Kwa Nahurumwene', 'Kwa Zomvela', 'Kwa Mwinyi', 'Kwa Binti Hassani', 'Mikoroshoni', 'Kwa Ngomeke', 'Kwa Maupa', 'Kwa Chipaka', 'Kwa Nyasa', 'Kwa Omary', 'Bosco', 'Shuleni3', 'Pump House 2', 'Kwa Bakari Mussa', 'Tankini Binti Randi', 'Kwa Jambo', 'Kwa Mbeche', 'Mnarani', 'Kwa Yassin Athumani', 'Nandete2', 'Sokoni', 'Kwa Chopa', 'Kwa Ismail 2', 'Mchonda', 'Kwa Isenga', 'Misufini', 'Kwa Nkuna Machiha', 'Namatunu 2', 'Kwa Khashimu Thabiti', 'Kwa Muba', 'Kwa Yassin 2', 'Kwa Ndoji', 'Mpindindi', 'Kwa Chiwata', 'Kwa Sabina Muhaji', 'Kwa Rumeni 3', 'Kwa Mwenye Nakutu', 'Kwa Jjsuph Kuraishi', 'Kwa Abeda Issa', 'Kwa Mariamu', 'Kwa Mohamed Mole 2', 'Kwa Azizi', 'Kwa Shahala', 'Kwa Mlola 2', 'Kwa Bale', 'Mchonda1', 'Kulumero', 'Kwa Zainabu', 'Kwa Chiwata 2', 'Msikitini', 'Kwa Masisa1', 'Kwa Muhajio', 'Nikokwe', 'Kwa Chilumba Jabiri', 'Hospitali', 'Kwa Bonga', 'Shuleni4', 'Kwa Anord Japhari'}
#
# 1 Var Declarations
#     to_construct : Size=116, Index=to_construct_index
#         Key                    : Lower : Value : Upper : Fixed : Stale : Domain
#                     Barabarani :     0 :  None :     1 : False :  True : Boolean
#                          Bosco :     0 :  None :     1 : False :  True : Boolean
#                         Demuni :     0 :  None :     1 : False :  True : Boolean
#                       Demuni 2 :     0 :  None :     1 : False :  True : Boolean
#                      Hospitali :     0 :  None :     1 : False :  True : Boolean
#                       Kulumero :     0 :  None :     1 : False :  True : Boolean
#                 Kwa Abeda Issa :     0 :  None :     1 : False :  True : Boolean
#              Kwa Adamu Imelale :     0 :  None :     1 : False :  True : Boolean
#               Kwa Ally Mohamed :     0 :  None :     1 : False :  True : Boolean
#                 Kwa Ally Omary :     0 :  None :     1 : False :  True : Boolean
#                  Kwa Alukama 2 :     0 :  None :     1 : False :  True : Boolean
#              Kwa Anord Japhari :     0 :  None :     1 : False :  True : Boolean
#                  Kwa Awilakina :     0 :  None :     1 : False :  True : Boolean
#                      Kwa Azizi :     0 :  None :     1 : False :  True : Boolean
#               Kwa Bakari Mussa :     0 :  None :     1 : False :  True : Boolean
#                       Kwa Bale :     0 :  None :     1 : False :  True : Boolean
#              Kwa Binti Hassani :     0 :  None :     1 : False :  True : Boolean
#                      Kwa Bonga :     0 :  None :     1 : False :  True : Boolean
#                   Kwa Chikwalo :     0 :  None :     1 : False :  True : Boolean
#                    Kwa Chilala :     0 :  None :     1 : False :  True : Boolean
#                  Kwa Chilala 2 :     0 :  None :     1 : False :  True : Boolean
#            Kwa Chilumba Jabiri :     0 :  None :     1 : False :  True : Boolean
#                    Kwa Chipaka :     0 :  None :     1 : False :  True : Boolean
#                    Kwa Chiwata :     0 :  None :     1 : False :  True : Boolean
#                  Kwa Chiwata 2 :     0 :  None :     1 : False :  True : Boolean
#                      Kwa Chopa :     0 :  None :     1 : False :  True : Boolean
#              Kwa Ddwani Mteule :     0 :  None :     1 : False :  True : Boolean
#                    Kwa Ghohoni :     0 :  None :     1 : False :  True : Boolean
#                      Kwa Hamza :     0 :  None :     1 : False :  True : Boolean
#                    Kwa Hamza 3 :     0 :  None :     1 : False :  True : Boolean
#                     Kwa Isenga :     0 :  None :     1 : False :  True : Boolean
#                     Kwa Ismail :     0 :  None :     1 : False :  True : Boolean
#                   Kwa Ismail 2 :     0 :  None :     1 : False :  True : Boolean
#                      Kwa Jambo :     0 :  None :     1 : False :  True : Boolean
#            Kwa Jjsuph Kuraishi :     0 :  None :     1 : False :  True : Boolean
#                   Kwa Kalambwa :     0 :  None :     1 : False :  True : Boolean
#                      Kwa Kalha :     0 :  None :     1 : False :  True : Boolean
#                     Kwa Kaluma :     0 :  None :     1 : False :  True : Boolean
#             Kwa Kaweni Japhari :     0 :  None :     1 : False :  True : Boolean
#           Kwa Khashimu Thabiti :     0 :  None :     1 : False :  True : Boolean
#                    Kwa Lilonde :     0 :  None :     1 : False :  True : Boolean
#                   Kwa Makusudi :     0 :  None :     1 : False :  True : Boolean
#                    Kwa Mariamu :     0 :  None :     1 : False :  True : Boolean
#                     Kwa Masisa :     0 :  None :     1 : False :  True : Boolean
#                    Kwa Masisa1 :     0 :  None :     1 : False :  True : Boolean
#                      Kwa Maupa :     0 :  None :     1 : False :  True : Boolean
#                     Kwa Mbanga :     0 :  None :     1 : False :  True : Boolean
#                     Kwa Mbeche :     0 :  None :     1 : False :  True : Boolean
#                    Kwa Mlola 2 :     0 :  None :     1 : False :  True : Boolean
#           Kwa Mohamed Kantinda :     0 :  None :     1 : False :  True : Boolean
#               Kwa Mohamed Mole :     0 :  None :     1 : False :  True : Boolean
#             Kwa Mohamed Mole 2 :     0 :  None :     1 : False :  True : Boolean
#                      Kwa Mtuta :     0 :  None :     1 : False :  True : Boolean
#                       Kwa Muba :     0 :  None :     1 : False :  True : Boolean
#                    Kwa Muhajio :     0 :  None :     1 : False :  True : Boolean
#           Kwa Mwanahafa Rajabu :     0 :  None :     1 : False :  True : Boolean
#              Kwa Mwenye Nakutu :     0 :  None :     1 : False :  True : Boolean
#               Kwa Mwenyemaviha :     0 :  None :     1 : False :  True : Boolean
#                     Kwa Mwinyi :     0 :  None :     1 : False :  True : Boolean
#                Kwa Nahurumwene :     0 :  None :     1 : False :  True : Boolean
#                      Kwa Ndoji :     0 :  None :     1 : False :  True : Boolean
#                    Kwa Ngomeke :     0 :  None :     1 : False :  True : Boolean
#                     Kwa Nihiha :     0 :  None :     1 : False :  True : Boolean
#              Kwa Nkuna Machiha :     0 :  None :     1 : False :  True : Boolean
#                      Kwa Nyasa :     0 :  None :     1 : False :  True : Boolean
#                      Kwa Omary :     0 :  None :     1 : False :  True : Boolean
#                      Kwa Peter :     0 :  None :     1 : False :  True : Boolean
#            Kwa Rehema Athumani :     0 :  None :     1 : False :  True : Boolean
#                     Kwa Rumeni :     0 :  None :     1 : False :  True : Boolean
#                   Kwa Rumeni 2 :     0 :  None :     1 : False :  True : Boolean
#                   Kwa Rumeni 3 :     0 :  None :     1 : False :  True : Boolean
#              Kwa Sabina Muhaji :     0 :  None :     1 : False :  True : Boolean
#                Kwa Salimu Ally :     0 :  None :     1 : False :  True : Boolean
#                    Kwa Shahala :     0 :  None :     1 : False :  True : Boolean
#                      Kwa Sitta :     0 :  None :     1 : False :  True : Boolean
#                     Kwa Tindwa :     0 :  None :     1 : False :  True : Boolean
#                     Kwa Wiliam :     0 :  None :     1 : False :  True : Boolean
#                     Kwa Yassin :     0 :  None :     1 : False :  True : Boolean
#                   Kwa Yassin 2 :     0 :  None :     1 : False :  True : Boolean
#            Kwa Yassin Athumani :     0 :  None :     1 : False :  True : Boolean
#              Kwa Yusuph Namoyo :     0 :  None :     1 : False :  True : Boolean
#                    Kwa Zainabu :     0 :  None :     1 : False :  True : Boolean
#              Kwa Zena Rajabu 2 :     0 :  None :     1 : False :  True : Boolean
#                    Kwa Zomvela :     0 :  None :     1 : False :  True : Boolean
#                         Likuku :     0 :  None :     1 : False :  True : Boolean
#                   Lukwika Camp :     0 :  None :     1 : False :  True : Boolean
#                        Mchonda :     0 :  None :     1 : False :  True : Boolean
#                       Mchonda1 :     0 :  None :     1 : False :  True : Boolean
#                    Mikoroshoni :     0 :  None :     1 : False :  True : Boolean
#                       Minazini :     0 :  None :     1 : False :  True : Boolean
#                        Mission :     0 :  None :     1 : False :  True : Boolean
#                       Misufini :     0 :  None :     1 : False :  True : Boolean
#                         Mkalia :     0 :  None :     1 : False :  True : Boolean
#                     Mkoroshoni :     0 :  None :     1 : False :  True : Boolean
#                   Mkoroshoni 2 :     0 :  None :     1 : False :  True : Boolean
#                        Mnarani :     0 :  None :     1 : False :  True : Boolean
#                      Mpindindi :     0 :  None :     1 : False :  True : Boolean
#                      Msikitini :     0 :  None :     1 : False :  True : Boolean
#                       Namajani :     0 :  None :     1 : False :  True : Boolean
#                     Namatunu 1 :     0 :  None :     1 : False :  True : Boolean
#                     Namatunu 2 :     0 :  None :     1 : False :  True : Boolean
#                        Nandete :     0 :  None :     1 : False :  True : Boolean
#                       Nandete1 :     0 :  None :     1 : False :  True : Boolean
#                       Nandete2 :     0 :  None :     1 : False :  True : Boolean
#                  Ngangasimiche :     0 :  None :     1 : False :  True : Boolean
#                        Nikokwe :     0 :  None :     1 : False :  True : Boolean
#                   Pump House 2 :     0 :  None :     1 : False :  True : Boolean
#         Shule Ya Msingi Chungu :     0 :  None :     1 : False :  True : Boolean
#                        Shuleni :     0 :  None :     1 : False :  True : Boolean
#                       Shuleni1 :     0 :  None :     1 : False :  True : Boolean
#                       Shuleni2 :     0 :  None :     1 : False :  True : Boolean
#                       Shuleni3 :     0 :  None :     1 : False :  True : Boolean
#                       Shuleni4 :     0 :  None :     1 : False :  True : Boolean
#                         Sokoni :     0 :  None :     1 : False :  True : Boolean
#            Tankini Binti Randi :     0 :  None :     1 : False :  True : Boolean
#           Zahanati Ya Nanyumbu :     0 :  None :     1 : False :  True : Boolean
#
# 1 Objective Declarations
#     obj : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : minimize : 100.0*to_construct[Zahanati Ya Nanyumbu] + 100.0*to_construct[Kwa Zena Rajabu 2] + 102.5*to_construct[Namajani] + 100.0*to_construct[Kwa Peter] + 100.0*to_construct[Mission] + 100.0*to_construct[Kwa Chikwalo] + 100.0*to_construct[Minazini] + 100.0*to_construct[Kwa Ally Omary] + 100.0*to_construct[Nandete] + 100.0*to_construct[Kwa Rehema Athumani] + 101.0*to_construct[Kwa Ally Mohamed] + 100.0*to_construct[Shuleni] + 100.0*to_construct[Kwa Kalha] + 100.0*to_construct[Kwa Ghohoni] + 100.0*to_construct[Kwa Yusuph Namoyo] + 100.0*to_construct[Kwa Kaluma] + 100.0*to_construct[Kwa Hamza 3] + 100.0*to_construct[Kwa Ismail] + 100.0*to_construct[Mkalia] + 100.0*to_construct[Likuku] + 100.0*to_construct[Kwa Rumeni 2] + 100.0*to_construct[Namatunu 1] + 100.0*to_construct[Kwa Mbanga] + 100.0*to_construct[Mkoroshoni] + 100.0*to_construct[Kwa Tindwa] + 100.0*to_construct[Kwa Masisa] + 100.0*to_construct[Shuleni1] + 100.0*to_construct[Kwa Mtuta] + 100.0*to_construct[Kwa Mwenyemaviha] + 100.0*to_construct[Demuni] + 100.0*to_construct[Kwa Wiliam] + 100.0*to_construct[Kwa Sitta] + 100.0*to_construct[Kwa Rumeni] + 100.0*to_construct[Kwa Ddwani Mteule] + 100.0*to_construct[Kwa Yassin] + 100.0*to_construct[Kwa Kaweni Japhari] + 100.0*to_construct[Lukwika Camp] + 100.0*to_construct[Mkoroshoni 2] + 100.0*to_construct[Shuleni2] + 100.0*to_construct[Kwa Mwanahafa Rajabu] + 100.0*to_construct[Kwa Nihiha] + 100.0*to_construct[Shule Ya Msingi Chungu] + 100.0*to_construct[Kwa Alukama 2] + 100.0*to_construct[Kwa Kalambwa] + 102.5*to_construct[Kwa Salimu Ally] + 100.0*to_construct[Kwa Lilonde] + 100.0*to_construct[Ngangasimiche] + 100.0*to_construct[Kwa Mohamed Kantinda] + 100.0*to_construct[Kwa Adamu Imelale] + 100.0*to_construct[Kwa Chilala 2] + 100.0*to_construct[Kwa Mohamed Mole] + 100.0*to_construct[Nandete1] + 100.0*to_construct[Kwa Makusudi] + 100.0*to_construct[Kwa Awilakina] + 100.0*to_construct[Barabarani] + 100.0*to_construct[Kwa Chilala] + 100.0*to_construct[Kwa Hamza] + 100.0*to_construct[Demuni 2] + 100.0*to_construct[Kwa Nahurumwene] + 102.5*to_construct[Kwa Zomvela] + 100.0*to_construct[Kwa Mwinyi] + 100.0*to_construct[Kwa Binti Hassani] + 100.0*to_construct[Mikoroshoni] + 100.0*to_construct[Kwa Ngomeke] + 100.0*to_construct[Kwa Maupa] + 100.0*to_construct[Kwa Chipaka] + 100.0*to_construct[Kwa Nyasa] + 100.0*to_construct[Kwa Omary] + 100.0*to_construct[Bosco] + 100.0*to_construct[Shuleni3] + 100.0*to_construct[Pump House 2] + 100.0*to_construct[Kwa Bakari Mussa] + 100.0*to_construct[Tankini Binti Randi] + 100.0*to_construct[Kwa Jambo] + 100.0*to_construct[Kwa Mbeche] + 100.0*to_construct[Mnarani] + 100.0*to_construct[Kwa Yassin Athumani] + 100.0*to_construct[Nandete2] + 105.0*to_construct[Sokoni] + 101.0*to_construct[Kwa Chopa] + 100.0*to_construct[Kwa Ismail 2] + 100.0*to_construct[Mchonda] + 101.0*to_construct[Kwa Isenga] + 102.5*to_construct[Misufini] + 100.0*to_construct[Kwa Nkuna Machiha] + 100.0*to_construct[Namatunu 2] + 100.0*to_construct[Kwa Khashimu Thabiti] + 100.0*to_construct[Kwa Muba] + 102.5*to_construct[Kwa Yassin 2] + 100.0*to_construct[Kwa Ndoji] + 100.0*to_construct[Mpindindi] + 100.0*to_construct[Kwa Chiwata] + 100.0*to_construct[Kwa Sabina Muhaji] + 100.0*to_construct[Kwa Rumeni 3] + 100.0*to_construct[Kwa Mwenye Nakutu] + 100.0*to_construct[Kwa Jjsuph Kuraishi] + 100.0*to_construct[Kwa Abeda Issa] + 100.0*to_construct[Kwa Mariamu] + 100.0*to_construct[Kwa Mohamed Mole 2] + 100.0*to_construct[Kwa Azizi] + 100.0*to_construct[Kwa Shahala] + 100.0*to_construct[Kwa Mlola 2] + 100.0*to_construct[Kwa Bale] + 100.0*to_construct[Mchonda1] + 100.0*to_construct[Kulumero] + 100.0*to_construct[Kwa Zainabu] + 100.0*to_construct[Kwa Chiwata 2] + 100.0*to_construct[Msikitini] + 100.0*to_construct[Kwa Masisa1] + 100.0*to_construct[Kwa Muhajio] + 100.0*to_construct[Nikokwe] + 101.5*to_construct[Kwa Chilumba Jabiri] + 100.0*to_construct[Hospitali] + 100.0*to_construct[Kwa Bonga] + 100.0*to_construct[Shul ...
#
# 1 Constraint Declarations
#     population_con : Size=0, Index=None, Active=True
#         Key : Lower : Body : Upper : Active
#
# 4 Declarations: to_construct_index to_construct obj population_con

# %% [markdown]
# The output is the minimal total cost it takes to either repair or transport water to each pump, as well as a list of boolean values, 1 if the pump is to be repaired and 0 if the pump is to be transported water.

# %%
opt = pe.SolverFactory('glpk', executable='/usr/bin/glpsol')
results = opt.solve(pump)

print('\nCost = ', pump.obj())
pump.display()
# Out:
# WARNING: Empty constraint block written in LP format - solver may error
#
# Cost =  11622.0
# Model unknown
#
#   Variables:
#     to_construct : Size=116, Index=to_construct_index
#         Key                    : Lower : Value : Upper : Fixed : Stale : Domain
#                     Barabarani :     0 :   1.0 :     1 : False : False : Boolean
#                          Bosco :     0 :   1.0 :     1 : False : False : Boolean
#                         Demuni :     0 :   1.0 :     1 : False : False : Boolean
#                       Demuni 2 :     0 :   1.0 :     1 : False : False : Boolean
#                      Hospitali :     0 :   1.0 :     1 : False : False : Boolean
#                       Kulumero :     0 :   1.0 :     1 : False : False : Boolean
#                 Kwa Abeda Issa :     0 :   1.0 :     1 : False : False : Boolean
#              Kwa Adamu Imelale :     0 :   1.0 :     1 : False : False : Boolean
#               Kwa Ally Mohamed :     0 :   1.0 :     1 : False : False : Boolean
#                 Kwa Ally Omary :     0 :   1.0 :     1 : False : False : Boolean
#                  Kwa Alukama 2 :     0 :   1.0 :     1 : False : False : Boolean
#              Kwa Anord Japhari :     0 :   1.0 :     1 : False : False : Boolean
#                  Kwa Awilakina :     0 :   1.0 :     1 : False : False : Boolean
#                      Kwa Azizi :     0 :   1.0 :     1 : False : False : Boolean
#               Kwa Bakari Mussa :     0 :   1.0 :     1 : False : False : Boolean
#                       Kwa Bale :     0 :   1.0 :     1 : False : False : Boolean
#              Kwa Binti Hassani :     0 :   1.0 :     1 : False : False : Boolean
#                      Kwa Bonga :     0 :   1.0 :     1 : False : False : Boolean
#                   Kwa Chikwalo :     0 :   1.0 :     1 : False : False : Boolean
#                    Kwa Chilala :     0 :   1.0 :     1 : False : False : Boolean
#                  Kwa Chilala 2 :     0 :   1.0 :     1 : False : False : Boolean
#            Kwa Chilumba Jabiri :     0 :   1.0 :     1 : False : False : Boolean
#                    Kwa Chipaka :     0 :   1.0 :     1 : False : False : Boolean
#                    Kwa Chiwata :     0 :   1.0 :     1 : False : False : Boolean
#                  Kwa Chiwata 2 :     0 :   1.0 :     1 : False : False : Boolean
#                      Kwa Chopa :     0 :   1.0 :     1 : False : False : Boolean
#              Kwa Ddwani Mteule :     0 :   1.0 :     1 : False : False : Boolean
#                    Kwa Ghohoni :     0 :   1.0 :     1 : False : False : Boolean
#                      Kwa Hamza :     0 :   1.0 :     1 : False : False : Boolean
#                    Kwa Hamza 3 :     0 :   1.0 :     1 : False : False : Boolean
#                     Kwa Isenga :     0 :   1.0 :     1 : False : False : Boolean
#                     Kwa Ismail :     0 :   1.0 :     1 : False : False : Boolean
#                   Kwa Ismail 2 :     0 :   1.0 :     1 : False : False : Boolean
#                      Kwa Jambo :     0 :   1.0 :     1 : False : False : Boolean
#            Kwa Jjsuph Kuraishi :     0 :   1.0 :     1 : False : False : Boolean
#                   Kwa Kalambwa :     0 :   1.0 :     1 : False : False : Boolean
#                      Kwa Kalha :     0 :   1.0 :     1 : False : False : Boolean
#                     Kwa Kaluma :     0 :   1.0 :     1 : False : False : Boolean
#             Kwa Kaweni Japhari :     0 :   1.0 :     1 : False : False : Boolean
#           Kwa Khashimu Thabiti :     0 :   1.0 :     1 : False : False : Boolean
#                    Kwa Lilonde :     0 :   1.0 :     1 : False : False : Boolean
#                   Kwa Makusudi :     0 :   1.0 :     1 : False : False : Boolean
#                    Kwa Mariamu :     0 :   1.0 :     1 : False : False : Boolean
#                     Kwa Masisa :     0 :   1.0 :     1 : False : False : Boolean
#                    Kwa Masisa1 :     0 :   1.0 :     1 : False : False : Boolean
#                      Kwa Maupa :     0 :   1.0 :     1 : False : False : Boolean
#                     Kwa Mbanga :     0 :   1.0 :     1 : False : False : Boolean
#                     Kwa Mbeche :     0 :   1.0 :     1 : False : False : Boolean
#                    Kwa Mlola 2 :     0 :   1.0 :     1 : False : False : Boolean
#           Kwa Mohamed Kantinda :     0 :   1.0 :     1 : False : False : Boolean
#               Kwa Mohamed Mole :     0 :   1.0 :     1 : False : False : Boolean
#             Kwa Mohamed Mole 2 :     0 :   1.0 :     1 : False : False : Boolean
#                      Kwa Mtuta :     0 :   1.0 :     1 : False : False : Boolean
#                       Kwa Muba :     0 :   1.0 :     1 : False : False : Boolean
#                    Kwa Muhajio :     0 :   1.0 :     1 : False : False : Boolean
#           Kwa Mwanahafa Rajabu :     0 :   1.0 :     1 : False : False : Boolean
#              Kwa Mwenye Nakutu :     0 :   1.0 :     1 : False : False : Boolean
#               Kwa Mwenyemaviha :     0 :   1.0 :     1 : False : False : Boolean
#                     Kwa Mwinyi :     0 :   1.0 :     1 : False : False : Boolean
#                Kwa Nahurumwene :     0 :   1.0 :     1 : False : False : Boolean
#                      Kwa Ndoji :     0 :   1.0 :     1 : False : False : Boolean
#                    Kwa Ngomeke :     0 :   1.0 :     1 : False : False : Boolean
#                     Kwa Nihiha :     0 :   1.0 :     1 : False : False : Boolean
#              Kwa Nkuna Machiha :     0 :   1.0 :     1 : False : False : Boolean
#                      Kwa Nyasa :     0 :   1.0 :     1 : False : False : Boolean
#                      Kwa Omary :     0 :   1.0 :     1 : False : False : Boolean
#                      Kwa Peter :     0 :   1.0 :     1 : False : False : Boolean
#            Kwa Rehema Athumani :     0 :   1.0 :     1 : False : False : Boolean
#                     Kwa Rumeni :     0 :   1.0 :     1 : False : False : Boolean
#                   Kwa Rumeni 2 :     0 :   1.0 :     1 : False : False : Boolean
#                   Kwa Rumeni 3 :     0 :   1.0 :     1 : False : False : Boolean
#              Kwa Sabina Muhaji :     0 :   1.0 :     1 : False : False : Boolean
#                Kwa Salimu Ally :     0 :   1.0 :     1 : False : False : Boolean
#                    Kwa Shahala :     0 :   1.0 :     1 : False : False : Boolean
#                      Kwa Sitta :     0 :   1.0 :     1 : False : False : Boolean
#                     Kwa Tindwa :     0 :   1.0 :     1 : False : False : Boolean
#                     Kwa Wiliam :     0 :   1.0 :     1 : False : False : Boolean
#                     Kwa Yassin :     0 :   1.0 :     1 : False : False : Boolean
#                   Kwa Yassin 2 :     0 :   1.0 :     1 : False : False : Boolean
#            Kwa Yassin Athumani :     0 :   1.0 :     1 : False : False : Boolean
#              Kwa Yusuph Namoyo :     0 :   1.0 :     1 : False : False : Boolean
#                    Kwa Zainabu :     0 :   1.0 :     1 : False : False : Boolean
#              Kwa Zena Rajabu 2 :     0 :   1.0 :     1 : False : False : Boolean
#                    Kwa Zomvela :     0 :   1.0 :     1 : False : False : Boolean
#                         Likuku :     0 :   1.0 :     1 : False : False : Boolean
#                   Lukwika Camp :     0 :   1.0 :     1 : False : False : Boolean
#                        Mchonda :     0 :   1.0 :     1 : False : False : Boolean
#                       Mchonda1 :     0 :   1.0 :     1 : False : False : Boolean
#                    Mikoroshoni :     0 :   1.0 :     1 : False : False : Boolean
#                       Minazini :     0 :   1.0 :     1 : False : False : Boolean
#                        Mission :     0 :   1.0 :     1 : False : False : Boolean
#                       Misufini :     0 :   1.0 :     1 : False : False : Boolean
#                         Mkalia :     0 :   1.0 :     1 : False : False : Boolean
#                     Mkoroshoni :     0 :   1.0 :     1 : False : False : Boolean
#                   Mkoroshoni 2 :     0 :   1.0 :     1 : False : False : Boolean
#                        Mnarani :     0 :   1.0 :     1 : False : False : Boolean
#                      Mpindindi :     0 :   1.0 :     1 : False : False : Boolean
#                      Msikitini :     0 :   1.0 :     1 : False : False : Boolean
#                       Namajani :     0 :   1.0 :     1 : False : False : Boolean
#                     Namatunu 1 :     0 :   1.0 :     1 : False : False : Boolean
#                     Namatunu 2 :     0 :   1.0 :     1 : False : False : Boolean
#                        Nandete :     0 :   1.0 :     1 : False : False : Boolean
#                       Nandete1 :     0 :   1.0 :     1 : False : False : Boolean
#                       Nandete2 :     0 :   1.0 :     1 : False : False : Boolean
#                  Ngangasimiche :     0 :   1.0 :     1 : False : False : Boolean
#                        Nikokwe :     0 :   1.0 :     1 : False : False : Boolean
#                   Pump House 2 :     0 :   1.0 :     1 : False : False : Boolean
#         Shule Ya Msingi Chungu :     0 :   1.0 :     1 : False : False : Boolean
#                        Shuleni :     0 :   1.0 :     1 : False : False : Boolean
#                       Shuleni1 :     0 :   1.0 :     1 : False : False : Boolean
#                       Shuleni2 :     0 :   1.0 :     1 : False : False : Boolean
#                       Shuleni3 :     0 :   1.0 :     1 : False : False : Boolean
#                       Shuleni4 :     0 :   1.0 :     1 : False : False : Boolean
#                         Sokoni :     0 :   1.0 :     1 : False : False : Boolean
#            Tankini Binti Randi :     0 :   1.0 :     1 : False : False : Boolean
#           Zahanati Ya Nanyumbu :     0 :   1.0 :     1 : False : False : Boolean
#
#   Objectives:
#     obj : Size=1, Index=None, Active=True
#         Key  : Active : Value
#         None :   True : 11622.0
#
#   Constraints:
#     population_con : Size=0
#         Key : Lower : Body : Upper
